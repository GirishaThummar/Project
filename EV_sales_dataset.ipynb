# %% [markdown]
# <a href="https://colab.research.google.com/github/GirishaThummar/Project/blob/main/EV_sales_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
reviews = pd.read_csv("/content/drive/MyDrive/EV_dataset/EV_Dataset.csv",index_col=0)
reviews
reviews.shape
# Out:
# (96845, 7)

# %%
reviews.to_csv("EV_Dataset.csv")

# %%
#reviews.head()
#wine_reviews.head(10)
#reviews.head(-10)
reviews.tail(-100)
# Out:
#        Month_Name       Date                     State  \
# Year
# 2014.0        jan   1/1/2014              Chhattisgarh
# 2014.0        jan   1/1/2014              Chhattisgarh
# 2014.0        jan   1/1/2014              Chhattisgarh
# 2014.0        jan   1/1/2014              Chhattisgarh
# 2014.0        jan   1/1/2014              Chhattisgarh
# ...           ...        ...                       ...
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
#
#                             Vehicle_Class Vehicle_Category Vehicle_Type  \
# Year
# 2014.0                          HARVESTER           Others       Others
# 2014.0                           MAXI CAB           Others       Others
# ...

# %% [markdown]
# # Indexing, Selecting & Assigning

# %%
reviews.head()
# Out:
#        Month_Name      Date           State         Vehicle_Class  \
# Year
# 2014.0        jan  1/1/2014  Andhra Pradesh       ADAPTED VEHICLE
# 2014.0        jan  1/1/2014  Andhra Pradesh  AGRICULTURAL TRACTOR
# 2014.0        jan  1/1/2014  Andhra Pradesh             AMBULANCE
# 2014.0        jan  1/1/2014  Andhra Pradesh   ARTICULATED VEHICLE
# 2014.0        jan  1/1/2014  Andhra Pradesh                   BUS
#
#        Vehicle_Category Vehicle_Type  EV_Sales_Quantity
# Year
# 2014.0           Others       Others                0.0
# 2014.0           Others       Others                0.0
# 2014.0           Others       Others                0.0
# 2014.0           Others       Others                0.0
# 2014.0              Bus          Bus                0.0

# %%
reviews=reviews.copy(deep=True)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96845 entries, 2014.0 to 2023.0
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Month_Name         96845 non-null  object
#  1   Date               96845 non-null  object
#  2   State              96845 non-null  object
#  3   Vehicle_Class      96845 non-null  object
#  4   Vehicle_Category   96845 non-null  object
#  5   Vehicle_Type       96845 non-null  object
#  6   EV_Sales_Quantity  96845 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 5.9+ MB

# %%
print(reviews.columns)
print(reviews.EV_Sales_Quantity.dtype)
print(reviews.dtypes)
# Out:
# Index(['Month_Name', 'Date', 'State', 'Vehicle_Class', 'Vehicle_Category',
#        'Vehicle_Type', 'EV_Sales_Quantity'],
#       dtype='object')
# float64
# Month_Name            object
# Date                  object
# State                 object
# Vehicle_Class         object
# Vehicle_Category      object
# Vehicle_Type          object
# EV_Sales_Quantity    float64
# dtype: object

# %%
reviews['State']
reviews.State
# Out:
# Year
# 2014.0              Andhra Pradesh
# 2014.0              Andhra Pradesh
# 2014.0              Andhra Pradesh
# 2014.0              Andhra Pradesh
# 2014.0              Andhra Pradesh
#                     ...
# 2023.0    Andaman & Nicobar Island
# 2023.0    Andaman & Nicobar Island
# 2023.0    Andaman & Nicobar Island
# 2023.0    Andaman & Nicobar Island
# 2023.0    Andaman & Nicobar Island
# Name: State, Length: 96845, dtype: object

# %%
reviews['EV_Sales_Quantity']
# Out:
# Year
# 2014.0    0.0
# 2014.0    0.0
# 2014.0    0.0
# 2014.0    0.0
# 2014.0    0.0
#          ...
# 2023.0    1.0
# 2023.0    5.0
# 2023.0    0.0
# 2023.0    0.0
# 2023.0    0.0
# Name: EV_Sales_Quantity, Length: 96845, dtype: float64

# %%
reviews['EV_Sales_Quantity'][:]
# Out:
# Year
# 2014.0    0.0
# 2014.0    0.0
# 2014.0    0.0
# 2014.0    0.0
# 2014.0    0.0
#          ...
# 2023.0    1.0
# 2023.0    5.0
# 2023.0    0.0
# 2023.0    0.0
# 2023.0    0.0
# Name: EV_Sales_Quantity, Length: 96845, dtype: float64

# %%
reviews.iloc[:, 0]
# Out:
# Year
# 2014.0    jan
# 2014.0    jan
# 2014.0    jan
# 2014.0    jan
# 2014.0    jan
#          ...
# 2023.0    dec
# 2023.0    dec
# 2023.0    dec
# 2023.0    dec
# 2023.0    dec
# Name: Month_Name, Length: 96845, dtype: object

# %%
reviews.iloc[[8,11,12], [1,2]]
# Out:
#             Date           State
# Year
# 2014.0  1/1/2014  Andhra Pradesh
# 2014.0  1/1/2014  Andhra Pradesh
# 2014.0  1/1/2014  Andhra Pradesh

# %%
reviews.iloc[:3, 0]
# Out:
# Year
# 2014.0    jan
# 2014.0    jan
# 2014.0    jan
# Name: Month_Name, dtype: object

# %%
reviews.iloc[[0, 1, 2], 1]
# Out:
# Year
# 2014.0    1/1/2014
# 2014.0    1/1/2014
# 2014.0    1/1/2014
# Name: Date, dtype: object

# %%
reviews.iloc[5]
# Out:
# Month_Name                      jan
# Date                       1/1/2014
# State                Andhra Pradesh
# Vehicle_Class              CASH VAN
# Vehicle_Category             Others
# Vehicle_Type                 Others
# EV_Sales_Quantity               0.0
# Name: 2014.0, dtype: object

# %%
reviews.loc[:, ['Month_Name', 'Vehicle_Category', 'EV_Sales_Quantity']]
# Out:
#        Month_Name Vehicle_Category  EV_Sales_Quantity
# Year
# 2014.0        jan           Others                0.0
# 2014.0        jan           Others                0.0
# 2014.0        jan           Others                0.0
# 2014.0        jan           Others                0.0
# 2014.0        jan              Bus                0.0
# ...           ...              ...                ...
# 2023.0        dec       4-Wheelers                1.0
# 2023.0        dec       2-Wheelers                5.0
# 2023.0        dec              Bus                0.0
# 2023.0        dec       3-Wheelers                0.0
# 2023.0        dec       3-Wheelers                0.0
#
# [96845 rows x 3 columns]

# %% [markdown]
# # Summary Functions and Maps

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96845 entries, 2014.0 to 2023.0
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Month_Name         96845 non-null  object
#  1   Date               96845 non-null  object
#  2   State              96845 non-null  object
#  3   Vehicle_Class      96845 non-null  object
#  4   Vehicle_Category   96845 non-null  object
#  5   Vehicle_Type       96845 non-null  object
#  6   EV_Sales_Quantity  96845 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 7.9+ MB

# %%
reviews.describe()
# Out:
#        EV_Sales_Quantity
# count       96845.000000
# mean           37.108896
# std           431.566675
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max         20584.000000

# %%
reviews.Vehicle_Type.describe()
# Out:
# count      96845
# unique        12
# top       Others
# freq       54423
# Name: Vehicle_Type, dtype: object

# %%
median_vl = reviews.EV_Sales_Quantity.median()

# %%
print(reviews.Vehicle_Type.unique())
print(reviews.Vehicle_Type.unique().size)
# Out:
# ['Others' 'Bus' 'Institution Bus' '2W_Personal' '4W_Shared' '4W_Personal'
#  '3W_Shared' '3W_Personal' '3W_Goods' '2W_Shared' '3W_Shared_LowSpeed'
#  '3W_Goods_LowSpeed']
# 12

# %%
reviews.EV_Sales_Quantity.value_counts()
# Out:
# EV_Sales_Quantity
# 0.0        82783
# 1.0         2481
# 2.0         1138
# 3.0          775
# 4.0          549
#            ...
# 3039.0         1
# 2353.0         1
# 955.0          1
# 10506.0        1
# 5380.0         1
# Name: count, Length: 1447, dtype: int64

# %%
#print(reviews.points.mean())
#print(reviews.points.std())
review_EV_Sales_Quantity_mean = reviews.EV_Sales_Quantity.mean()
print(review_EV_Sales_Quantity_mean)
# reviews.EV_Sales_Quantity = reviews.points - review_points_mean
print(reviews.EV_Sales_Quantity)
# format = lambda x: '%.2f' % x
# reviews['points'].map(format)
# Out:
# 37.10889565801022
# Year
# 2014.0    0.0
# 2014.0    0.0
# 2014.0    0.0
# 2014.0    0.0
# 2014.0    0.0
#          ...
# 2023.0    1.0
# 2023.0    5.0
# 2023.0    0.0
# 2023.0    0.0
# 2023.0    0.0
# Name: EV_Sales_Quantity, Length: 96845, dtype: float64

# %%
reviews.EV_Sales_Quantity = reviews.EV_Sales_Quantity + " - " + reviews.Vehicle_Type
reviews.EV_Sales_Quantity
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-49-b55ae82d9214> in <cell line: 1>()
# ----> 1 reviews.EV_Sales_Quantity = reviews.EV_Sales_Quantity + " - " + reviews.Vehicle_Type
#       2 reviews.EV_Sales_Quantity
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __add__(self, other)
#     184         moose     3.0     NaN
#     185         """
# --> 186         return self._arith_method(other, operator.add)
#     187
#     188     @unpack_zerodim_and_defer("__radd__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _arith_method(self, other, op)
# ...

# %% [markdown]
# # Grouping and Sorting

# %%
reviews.groupby('EV_Sales_Quantity').EV_Sales_Quantity.count()
# Out:
# EV_Sales_Quantity
# 0.0        82783
# 1.0         2481
# 2.0         1138
# 3.0          775
# 4.0          549
#            ...
# 18769.0        1
# 19486.0        1
# 19908.0        1
# 20352.0        1
# 20584.0        1
# Name: EV_Sales_Quantity, Length: 1447, dtype: int64

# %%
import pandas as pd
reviews.groupby('EV_Sales_Quantity')

# %%
countries_reviewed = reviews.groupby(['EV_Sales_Quantity'])
countries_reviewed

# %%
countries_reviewed

# %%
reviews.sort_values(by='EV_Sales_Quantity')
# Out:
#        Month_Name       Date           State                Vehicle_Class  \
# Year
# 2014.0        jan   1/1/2014  Andhra Pradesh              ADAPTED VEHICLE
# 2020.0        aug   8/1/2020      DNH and DD    THREE WHEELER (PASSENGER)
# 2020.0        aug   8/1/2020      DNH and DD      PRIVATE SERVICE VEHICLE
# 2020.0        aug   8/1/2020      DNH and DD  MOTORISED CYCLE (CC > 25CC)
# 2020.0        aug   8/1/2020      DNH and DD                    MOTOR CAR
# ...           ...        ...             ...                          ...
# 2023.0        jul   7/1/2023   Uttar Pradesh                E-RICKSHAW(P)
# 2023.0        sep   9/1/2023   Uttar Pradesh                E-RICKSHAW(P)
# 2023.0        may   5/1/2023     Maharashtra              M-CYCLE/SCOOTER
# 2023.0        dec  12/1/2023   Uttar Pradesh                E-RICKSHAW(P)
# 2023.0        aug   8/1/2023   Uttar Pradesh                E-RICKSHAW(P)
#
#        Vehicle_Category        Vehicle_Type  EV_Sales_Quantity
# Year
# ...

# %%
reviews.sort_values(by='EV_Sales_Quantity')
# Out:
#        Month_Name       Date           State                Vehicle_Class  \
# Year
# 2014.0        jan   1/1/2014  Andhra Pradesh              ADAPTED VEHICLE
# 2020.0        aug   8/1/2020      DNH and DD    THREE WHEELER (PASSENGER)
# 2020.0        aug   8/1/2020      DNH and DD      PRIVATE SERVICE VEHICLE
# 2020.0        aug   8/1/2020      DNH and DD  MOTORISED CYCLE (CC > 25CC)
# 2020.0        aug   8/1/2020      DNH and DD                    MOTOR CAR
# ...           ...        ...             ...                          ...
# 2023.0        jul   7/1/2023   Uttar Pradesh                E-RICKSHAW(P)
# 2023.0        sep   9/1/2023   Uttar Pradesh                E-RICKSHAW(P)
# 2023.0        may   5/1/2023     Maharashtra              M-CYCLE/SCOOTER
# 2023.0        dec  12/1/2023   Uttar Pradesh                E-RICKSHAW(P)
# 2023.0        aug   8/1/2023   Uttar Pradesh                E-RICKSHAW(P)
#
#        Vehicle_Category        Vehicle_Type  EV_Sales_Quantity
# Year
# ...

# %%
reviews.sort_values(by=['EV_Sales_Quantity', 'Vehicle_Type','Vehicle_Category'])
# Out:
#        Month_Name       Date                     State    Vehicle_Class  \
# Year
# 2014.0        jan   1/1/2014         Arunachal Pradesh  M-CYCLE/SCOOTER
# 2014.0        jan   1/1/2014         Arunachal Pradesh            MOPED
# 2014.0        jan   1/1/2014                     Assam  M-CYCLE/SCOOTER
# 2014.0        jan   1/1/2014                     Assam            MOPED
# 2014.0        jan   1/1/2014  Andaman & Nicobar Island  M-CYCLE/SCOOTER
# ...           ...        ...                       ...              ...
# 2023.0        jul   7/1/2023             Uttar Pradesh    E-RICKSHAW(P)
# 2023.0        sep   9/1/2023             Uttar Pradesh    E-RICKSHAW(P)
# 2023.0        may   5/1/2023               Maharashtra  M-CYCLE/SCOOTER
# 2023.0        dec  12/1/2023             Uttar Pradesh    E-RICKSHAW(P)
# 2023.0        aug   8/1/2023             Uttar Pradesh    E-RICKSHAW(P)
#
#        Vehicle_Category        Vehicle_Type  EV_Sales_Quantity
# Year
# ...

# %% [markdown]
# # Data Types and Missing Values

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96845 entries, 2014.0 to 2023.0
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Month_Name         96845 non-null  object
#  1   Date               96845 non-null  object
#  2   State              96845 non-null  object
#  3   Vehicle_Class      96845 non-null  object
#  4   Vehicle_Category   96845 non-null  object
#  5   Vehicle_Type       96845 non-null  object
#  6   EV_Sales_Quantity  96845 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 7.9+ MB

# %%
reviews.dtypes
# Out:
# Month_Name            object
# Date                  object
# State                 object
# Vehicle_Class         object
# Vehicle_Category      object
# Vehicle_Type          object
# EV_Sales_Quantity    float64
# dtype: object

# %%
reviews.Vehicle_Category = reviews.Vehicle_Category.astype('str')#Changed '' to 'str' to indicate string data type
#astype('str') converts to string type in pandas

print(reviews.Vehicle_Category)
reviews.Vehicle_Category.dtype
# Out:
# Year
# 2014.0        Others
# 2014.0        Others
# 2014.0        Others
# 2014.0        Others
# 2014.0           Bus
#              ...
# 2023.0    4-Wheelers
# 2023.0    2-Wheelers
# 2023.0           Bus
# 2023.0    3-Wheelers
# 2023.0    3-Wheelers
# Name: Vehicle_Category, Length: 96845, dtype: object
# dtype('O')

# %%
#reviews[pd.notnull(reviews.region_2)]
reviews.Vehicle_Type.isna().sum()
# Out:
# 0

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96845 entries, 2014.0 to 2023.0
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Month_Name         96845 non-null  object
#  1   Date               96845 non-null  object
#  2   State              96845 non-null  object
#  3   Vehicle_Class      96845 non-null  object
#  4   Vehicle_Category   96845 non-null  object
#  5   Vehicle_Type       96845 non-null  object
#  6   EV_Sales_Quantity  96845 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 7.9+ MB

# %%
mode_Vehicle_Category = reviews.Vehicle_Category.mode()[0]  # [0] to get the first mode value
reviews.Vehicle_Category.fillna(reviews.Vehicle_Category.fillna(mode_Vehicle_Category, inplace=True)
,inplace=True)
reviews.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-28da372c724d> in <cell line: 2>()
#       1 mode_Vehicle_Category = reviews.Vehicle_Category.mode()[0]  # [0] to get the first mode value
# ----> 2 reviews.Vehicle_Category.fillna(reviews.Vehicle_Category.fillna(mode_Vehicle_Category, inplace=True)
#       3 ,inplace=True)
#       4 reviews.info()
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7291                     )
#    7292
# -> 7293         value, method = validate_fillna_kwargs(value, method)
#    7294         if method is not None:
#    7295             warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_validators.py in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     291
# ...

# %%
reviews.Vehicle_Type.fillna(("Unknown"),inplace=True)
reviews.Vehicle_Type
# Out:
# <ipython-input-78-f402e4eb70e6>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   reviews.Vehicle_Type.fillna(("Unknown"),inplace=True)
# Year
# 2014.0         Others
# 2014.0         Others
# 2014.0         Others
# 2014.0         Others
# 2014.0            Bus
#              ...
# 2023.0    4W_Personal
# 2023.0      2W_Shared
# 2023.0            Bus
# 2023.0       3W_Goods
# 2023.0      3W_Shared
# Name: Vehicle_Type, Length: 96845, dtype: object

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96845 entries, 2014.0 to 2023.0
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Month_Name         96845 non-null  object
#  1   Date               96845 non-null  object
#  2   State              96845 non-null  object
#  3   Vehicle_Class      96845 non-null  object
#  4   Vehicle_Category   96845 non-null  object
#  5   Vehicle_Type       96845 non-null  object
#  6   EV_Sales_Quantity  96845 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 7.9+ MB

# %%
reviews.drop('EV_Sales_Quantity',axis='columns',inplace=True)
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96845 entries, 2014.0 to 2023.0
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month_Name        96845 non-null  object
#  1   Date              96845 non-null  object
#  2   State             96845 non-null  object
#  3   Vehicle_Class     96845 non-null  object
#  4   Vehicle_Category  96845 non-null  object
#  5   Vehicle_Type      96845 non-null  object
# dtypes: object(6)
# memory usage: 7.2+ MB

# %%
# Assuming you want to use pandas' dropna() function to drop rows with missing values
import pandas as pd

# Replace 'reviews' with your DataFrame's actual name
reviews.dropna(inplace=True)

# %% [markdown]
# # Renaming and Combining

# %%
reviews.rename(columns={'EV_Sales_Quantity': 'Vehicle_Type'},inplace=True)
reviews.head()
# Out:
#        Month_Name      Date           State         Vehicle_Class  \
# Year
# 2014.0        jan  1/1/2014  Andhra Pradesh       ADAPTED VEHICLE
# 2014.0        jan  1/1/2014  Andhra Pradesh  AGRICULTURAL TRACTOR
# 2014.0        jan  1/1/2014  Andhra Pradesh             AMBULANCE
# 2014.0        jan  1/1/2014  Andhra Pradesh   ARTICULATED VEHICLE
# 2014.0        jan  1/1/2014  Andhra Pradesh                   BUS
#
#        Vehicle_Category Vehicle_Type
# Year
# 2014.0           Others       Others
# 2014.0           Others       Others
# 2014.0           Others       Others
# 2014.0           Others       Others
# 2014.0              Bus          Bus

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#        Month_Name       Date                     State  \
# Year
# 2014.0        jan   1/1/2014            Andhra Pradesh
# 2014.0        jan   1/1/2014            Andhra Pradesh
# 2014.0        jan   1/1/2014            Andhra Pradesh
# 2014.0        jan   1/1/2014            Andhra Pradesh
# 2014.0        jan   1/1/2014            Andhra Pradesh
# ...           ...        ...                       ...
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
# 2023.0        dec  12/1/2023  Andaman & Nicobar Island
#
#                             Vehicle_Class Vehicle_Category Vehicle_Type
# Year
# 2014.0                    ADAPTED VEHICLE           Others       Others
# 2014.0               AGRICULTURAL TRACTOR           Others       Others
# 2014.0                          AMBULANCE           Others       Others
# ...

# %%
reviews.to_csv('EV_Dataset.csv',index=False)
